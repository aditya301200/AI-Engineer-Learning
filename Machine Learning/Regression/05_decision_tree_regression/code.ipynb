# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## Importing Dataset

# %%
dataset = pd.read_csv("../../Datasets/Decision Tree regression/Position_Salaries.csv")
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ## Training the Dicision Tree Regression model on the whole dataset

# %%
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Predicting new result

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# ## Visulising the Decision Tree Regression results(higher resolution)

# %%
X_grid = np.arange(X.min(), X.max(), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor.predict(X_grid), color='blue')
plt.title("Truth or Bluff (Polynomial Regression)")
plt.xlabel('Position Label')
plt.ylabel('Salary')
plt.show()
